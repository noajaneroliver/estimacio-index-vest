# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
import numpy as np
import torch
import math
import pickle
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.pyplot as plt

# %%
data = '/content/drive/MyDrive/trajectories_imu/df_RGC.pkl'
with open(data, 'rb') as file:
    data = pickle.load(file)

label = '/content/drive/MyDrive/trajectories_imu/labels_RGC.pkl'
with open(label, 'rb') as file:
    labels = pickle.load(file)

labels = labels.astype(float)/100
labels = labels.values

# %%
data = np.reshape(data,(data.shape[0], data.shape[2],3))
print(data.shape,len(labels))
# Out:
# (102, 1127, 3) 102

# %%
def build_model(lr=0.001, units_gru=64, units_gru_2=32, units_dense = 16):
    model = tf.keras.Sequential()

    # Capa GRU 1
    model.add(layers.GRU(units_gru, return_sequences=True, input_shape=(data.shape[1], data.shape[2])))

    # Capa GRU 2
    model.add(layers.GRU(units_gru_2, return_sequences=False))

    # Capa totalment connectada
    model.add(layers.Dense(units_dense, activation='ReLU')) #relu per evitar la saturacio de gradients

    # Capa final totalment connectada amb funció d'activació sigmoide
    model.add(layers.Dense(1, activation='sigmoid'))

    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae']) #mean absoulte error com a mètrica

    return model

# %%
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)
print(y_train.shape, y_test.shape)

def create_dataloader(X_train, y_train, batch_size):
    dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
    dataset = dataset.shuffle(buffer_size=len(X_train)).batch(batch_size)
    return dataset
# Out:
# (81,) (21,)

# %% [markdown]
# # HYPERPARAMETER TUNNING

# %%
param_grid = {
    'lr': [0.001, 0.01, 0.1],  # Learning Rate
    'units_gru': [32, 64, 128],  # Unitats en la primera capa GRU
    'units_gru_2': [16, 32, 64],  # Unitats en la segona capa GRU,
    'units_dense': [8, 16, 32]
}

keras_model = KerasRegressor(build_fn=build_model, verbose=0) #especificar el contstructor del model + si volem imprimir el progres de l'entrenament

#cross-validation
grid_search = RandomizedSearchCV (keras_model, param_grid, cv=3)
grid_result = grid_search.fit(X_train, y_train)
# Out:
# <ipython-input-26-77f43cff3777>:8: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_model = KerasRegressor(build_fn=build_model, verbose=0) #especificar el contstructor del model + si volem imprimir el progres de l'entrenament

# %%
#evaluacio del model amb els millor hiperparàmetres
best_model = grid_result.best_estimator_.model
test_loss, test_mae = best_model.evaluate(X_test, y_test)
print("\nLoss al conjunt de prova:", test_loss)
print("Error abolut mitjà al conjunt de prova:", test_mae)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.2091 - mae: 0.3821
#
# Loss al conjunt de prova: 0.20906738936901093
# Error abolut mitjà al conjunt de prova: 0.38210591673851013

# %%
# Obtenir l'historial d'entrenament per a cada combinació d'hiperparàmetres
loss_history = []
for params, cv_results in zip(grid_result.cv_results_['params'], grid_result.cv_results_['mean_test_score']):
    model = build_model(**params)
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
    history = model.fit(X_train, y_train, batch_size=32, epochs=30, verbose=0)
    loss_history.append(history.history['loss'])

plt.figure(figsize=(10, 6))
for i, loss in enumerate(loss_history):
    plt.plot(range(1, len(loss)+1), loss, label=f"hiperparàmetres: {grid_result.cv_results_['params'][i]}")

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Evolució de la pèrdua durant l\'entrenament')
plt.legend()
plt.show()

# %%
print("Millors hiperparàmetres:")
print(grid_result.best_params_)

print("\nMillor score:")
print(grid_result.best_score_)
# Out:
# Millors hiperparàmetres:
# {'units_gru_2': 16, 'units_gru': 32, 'units_dense': 32, 'lr': 0.01}
#
# Millor score:
# -0.19138604402542114

# %%
# Emmagatzemar els hiperparàmetres
units_gru_2, units_gru, units_dense, lr = grid_result.best_params_['units_gru_2'], grid_result.best_params_['units_gru'], grid_result.best_params_['units_dense'], grid_result.best_params_['lr']
model = build_model(lr=lr, units_gru=units_gru, units_gru_2=units_gru_2, units_dense=units_dense)

#Diferents valors a provar
batch_sizes = [16, 32, 64]
epochs_values = [20, 30, 40]

loss_values = []
mae_values = []

for batch_size in batch_sizes:
    for epochs in epochs_values:
        train_dataset = create_dataloader(X_train, y_train, batch_size)
        history = model.fit(train_dataset, epochs=epochs, verbose=1)

        loss_values.append(history.history['loss'])
        mae_values.append(history.history['mae'])

#Graficar l'evolució de les proves (loss)
plt.figure(figsize=(10, 6))
for i, (batch_size, epochs) in enumerate(zip(batch_sizes * len(epochs_values), epochs_values * len(batch_sizes))):
    label = f"Batch Size: {batch_size}, Epochs: {epochs}"
    plt.plot(range(1, len(loss_values[i])+1), loss_values[i], label=label)

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Evolució de la pèrdua durant l\'entrenament')
plt.legend()
plt.show()

#Graficar l'evolució de les proves (mae)
plt.figure(figsize=(10, 6))
for i, (batch_size, epochs) in enumerate(zip(batch_sizes * len(epochs_values), epochs_values * len(batch_sizes))):
    label = f"Batch Size: {batch_size}, Epochs: {epochs}"
    plt.plot(range(1, len(mae_values[i])+1), mae_values[i], label=label)

plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.title('Evolució del MAE durant l\'entrenament')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 6/6 [==============================] - 12s 1s/step - loss: 0.2011 - mae: 0.3742
# Epoch 2/20
# 6/6 [==============================] - 6s 1s/step - loss: 0.1920 - mae: 0.3619
# Epoch 3/20
# 6/6 [==============================] - 8s 1s/step - loss: 0.1891 - mae: 0.3850
# Epoch 4/20
# 6/6 [==============================] - 6s 985ms/step - loss: 0.1760 - mae: 0.3584
# Epoch 5/20
# 6/6 [==============================] - 6s 997ms/step - loss: 0.1840 - mae: 0.3403
# Epoch 6/20
# 6/6 [==============================] - 7s 1s/step - loss: 0.1777 - mae: 0.3473
# Epoch 7/20
# 6/6 [==============================] - 6s 998ms/step - loss: 0.1768 - mae: 0.3698
# Epoch 8/20
# 6/6 [==============================] - 6s 1s/step - loss: 0.1804 - mae: 0.3533
# Epoch 9/20
# 6/6 [==============================] - 7s 1s/step - loss: 0.1802 - mae: 0.3766
# Epoch 10/20
# 6/6 [==============================] - 8s 1s/step - loss: 0.1845 - mae: 0.4035
# Epoch 11/20
# 6/6 [==============================] - 6s 1s/step - loss: 0.1750 - mae: 0.3667
# Epoch 12/20
# 6/6 [==============================] - 9s 2s/step - loss: 0.1743 - mae: 0.3663
# Epoch 13/20
# 6/6 [==============================] - 6s 993ms/step - loss: 0.1763 - mae: 0.3803
# Epoch 14/20
# 6/6 [==============================] - 7s 1s/step - loss: 0.1711 - mae: 0.3581
# Epoch 15/20
# 6/6 [==============================] - 6s 1s/step - loss: 0.1730 - mae: 0.3398
# Epoch 16/20
# 6/6 [==============================] - 6s 995ms/step - loss: 0.1749 - mae: 0.3663
# Epoch 17/20
# 6/6 [==============================] - 8s 1s/step - loss: 0.2007 - mae: 0.4262
# Epoch 18/20
# 6/6 [==============================] - 6s 998ms/step - loss: 0.2012 - mae: 0.4281
# Epoch 19/20
# 6/6 [==============================] - 8s 1s/step - loss: 0.1791 - mae: 0.3792
# Epoch 20/20
# 6/6 [==============================] - 7s 1s/step - loss: 0.1737 - mae: 0.3484
# Epoch 1/30
# 6/6 [==============================] - 7s 1s/step - loss: 0.1721 - mae: 0.3484
# Epoch 2/30
# 6/6 [==============================] - 8s 1s/step - loss: 0.1779 - mae: 0.3410
# Epoch 3/30
# 6/6 [==============================] - 6s 995ms/step - loss: 0.1726 - mae: 0.3548
# Epoch 4/30
# 6/6 [==============================] - 8s 1s/step - loss: 0.1733 - mae: 0.3747
# Epoch 5/30
# 6/6 [==============================] - 7s 1s/step - loss: 0.1703 - mae: 0.3623
# Epoch 6/30
# 6/6 [==============================] - 6s 994ms/step - loss: 0.1696 - mae: 0.3494
# Epoch 7/30
# 6/6 [==============================] - 8s 1s/step - loss: 0.1719 - mae: 0.3532
# Epoch 8/30
# 6/6 [==============================] - 6s 1s/step - loss: 0.1730 - mae: 0.3524
# Epoch 9/30
# 6/6 [==============================] - 7s 1s/step - loss: 0.1703 - mae: 0.3438
# Epoch 10/30
# 6/6 [==============================] - 7s 1s/step - loss: 0.1716 - mae: 0.3390
# Epoch 11/30
# 6/6 [==============================] - 7s 1s/step - loss: 0.1688 - mae: 0.3388
# Epoch 12/30
# 6/6 [==============================] - 8s 1s/step - loss: 0.1673 - mae: 0.3470
# Epoch 13/30
# 6/6 [==============================] - 8s 1s/step - loss: 0.1673 - mae: 0.3494
# Epoch 14/30
# 6/6 [==============================] - 8s 1s/step - loss: 0.1696 - mae: 0.3412
# Epoch 15/30
# 6/6 [==============================] - 6s 994ms/step - loss: 0.1793 - mae: 0.3609
# Epoch 16/30
# 6/6 [==============================] - 7s 1s/step - loss: 0.1739 - mae: 0.3780
# Epoch 17/30
# 6/6 [==============================] - 8s 1s/step - loss: 0.1740 - mae: 0.3797
# Epoch 18/30
# 6/6 [==============================] - 6s 1s/step - loss: 0.1672 - mae: 0.3590
# Epoch 19/30
# 6/6 [==============================] - 8s 1s/step - loss: 0.1665 - mae: 0.3384
# Epoch 20/30
# 6/6 [==============================] - 6s 1s/step - loss: 0.1715 - mae: 0.3488
# Epoch 21/30
# 6/6 [==============================] - 6s 1s/step - loss: 0.1870 - mae: 0.4004
# Epoch 22/30
# 6/6 [==============================] - 8s 1s/step - loss: 0.2098 - mae: 0.4392
# Epoch 23/30
# 6/6 [==============================] - 6s 1s/step - loss: 0.1724 - mae: 0.3710
# Epoch 24/30
# 6/6 [==============================] - 7s 1s/step - loss: 0.1758 - mae: 0.3333
# Epoch 25/30
# 6/6 [==============================] - 6s 1s/step - loss: 0.1699 - mae: 0.3568
# Epoch 26/30
# 6/6 [==============================] - 8s 1s/step - loss: 0.1750 - mae: 0.3782
# Epoch 27/30
# 6/6 [==============================] - 7s 1s/step - loss: 0.1733 - mae: 0.3458
# Epoch 28/30
# 6/6 [==============================] - 6s 1s/step - loss: 0.1756 - mae: 0.3342
# Epoch 29/30
# 6/6 [==============================] - 6s 1s/step - loss: 0.1709 - mae: 0.3363
# Epoch 30/30
# 6/6 [==============================] - 8s 1s/step - loss: 0.1699 - mae: 0.3367
# Epoch 1/40
# 6/6 [==============================] - 6s 1s/step - loss: 0.1758 - mae: 0.3384
# Epoch 2/40
# 6/6 [==============================] - 8s 1s/step - loss: 0.1753 - mae: 0.3393
# Epoch 3/40
# 6/6 [==============================] - 6s 1s/step - loss: 0.1736 - mae: 0.3691
# Epoch 4/40
# 6/6 [==============================] - 7s 1s/step - loss: 0.1745 - mae: 0.3764
# Epoch 5/40
# 6/6 [==============================] - 8s 1s/step - loss: 0.1728 - mae: 0.3744
# Epoch 6/40
# 6/6 [==============================] - 6s 1s/step - loss: 0.1694 - mae: 0.3602
# Epoch 7/40
# 6/6 [==============================] - 8s 1s/step - loss: 0.1703 - mae: 0.3292
# Epoch 8/40
# 6/6 [==============================] - 6s 997ms/step - loss: 0.1743 - mae: 0.3216
# Epoch 9/40
# 6/6 [==============================] - 6s 1s/step - loss: 0.1727 - mae: 0.3285
# Epoch 10/40
# 6/6 [==============================] - 8s 1s/step - loss: 0.1707 - mae: 0.3512
# Epoch 11/40
# 6/6 [==============================] - 7s 1s/step - loss: 0.1732 - mae: 0.3320
# Epoch 12/40
# 6/6 [==============================] - 6s 1s/step - loss: 0.1717 - mae: 0.3246
# Epoch 13/40
# 6/6 [==============================] - 6s 1s/step - loss: 0.1696 - mae: 0.3294
# Epoch 14/40
# 6/6 [==============================] - 7s 1s/step - loss: 0.1706 - mae: 0.3303
# Epoch 15/40
# 6/6 [==============================] - 6s 1s/step - loss: 0.1707 - mae: 0.3290
# Epoch 16/40
# 6/6 [==============================] - 8s 1s/step - loss: 0.1669 - mae: 0.3334
# Epoch 17/40
# 6/6 [==============================] - 6s 1s/step - loss: 0.1743 - mae: 0.3552
# Epoch 18/40
# 6/6 [==============================] - 8s 1s/step - loss: 0.1682 - mae: 0.3535
# Epoch 19/40
# 6/6 [==============================] - 6s 996ms/step - loss: 0.1753 - mae: 0.3745
# Epoch 20/40
# 6/6 [==============================] - 6s 991ms/step - loss: 0.1748 - mae: 0.3777
# Epoch 21/40
# 6/6 [==============================] - 7s 1s/step - loss: 0.1702 - mae: 0.3571
# Epoch 22/40
# 6/6 [==============================] - 6s 991ms/step - loss: 0.1719 - mae: 0.3424
# Epoch 23/40
# 6/6 [==============================] - 8s 1s/step - loss: 0.1708 - mae: 0.3365
# Epoch 24/40
# 6/6 [==============================] - 6s 1s/step - loss: 0.1679 - mae: 0.3347
# Epoch 25/40
# 6/6 [==============================] - 7s 1s/step - loss: 0.1676 - mae: 0.3377
# Epoch 26/40
# 6/6 [==============================] - 6s 993ms/step - loss: 0.1672 - mae: 0.3342
# Epoch 27/40
# 6/6 [==============================] - 6s 1s/step - loss: 0.1697 - mae: 0.3312
# Epoch 28/40
# 6/6 [==============================] - 8s 1s/step - loss: 0.1715 - mae: 0.3288
# Epoch 29/40
# 6/6 [==============================] - 7s 1s/step - loss: 0.1711 - mae: 0.3311
# Epoch 30/40
# 6/6 [==============================] - 6s 1s/step - loss: 0.1646 - mae: 0.3503
# Epoch 31/40
# 6/6 [==============================] - 6s 1s/step - loss: 0.1748 - mae: 0.3795
# Epoch 32/40
# 6/6 [==============================] - 7s 1s/step - loss: 0.1687 - mae: 0.3659
# Epoch 33/40
# 6/6 [==============================] - 6s 999ms/step - loss: 0.1665 - mae: 0.3434
# Epoch 34/40
# 6/6 [==============================] - 8s 1s/step - loss: 0.1697 - mae: 0.3275
# Epoch 35/40
# 6/6 [==============================] - 6s 1s/step - loss: 0.1686 - mae: 0.3452
# Epoch 36/40
# 6/6 [==============================] - 6s 1000ms/step - loss: 0.1669 - mae: 0.3575
# Epoch 37/40
# 6/6 [==============================] - 8s 1s/step - loss: 0.1682 - mae: 0.3654
# Epoch 38/40
# 6/6 [==============================] - 6s 1s/step - loss: 0.1810 - mae: 0.3929
# Epoch 39/40
# 6/6 [==============================] - 7s 1s/step - loss: 0.1758 - mae: 0.3836
# Epoch 40/40
# 6/6 [==============================] - 6s 997ms/step - loss: 0.1650 - mae: 0.3556
# Epoch 1/20
# 3/3 [==============================] - 3s 1s/step - loss: 0.1652 - mae: 0.3457
# Epoch 2/20
# 3/3 [==============================] - 3s 1s/step - loss: 0.1675 - mae: 0.3442
# Epoch 3/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.1640 - mae: 0.3376
# Epoch 4/20
# 3/3 [==============================] - 3s 1s/step - loss: 0.1649 - mae: 0.3363
# Epoch 5/20
# 3/3 [==============================] - 4s 2s/step - loss: 0.1651 - mae: 0.3358
# Epoch 6/20
# 3/3 [==============================] - 4s 2s/step - loss: 0.1654 - mae: 0.3378
# Epoch 7/20
# 3/3 [==============================] - 4s 1s/step - loss: 0.1646 - mae: 0.3384
# Epoch 8/20
# 3/3 [==============================] - 3s 1s/step - loss: 0.1640 - mae: 0.3382
# Epoch 9/20
# 3/3 [==============================] - 4s 2s/step - loss: 0.1641 - mae: 0.3385
# Epoch 10/20
# 3/3 [==============================] - 3s 1s/step - loss: 0.1636 - mae: 0.3367
# Epoch 11/20
# 3/3 [==============================] - 3s 1s/step - loss: 0.1635 - mae: 0.3355
# Epoch 12/20
# 3/3 [==============================] - 4s 1s/step - loss: 0.1636 - mae: 0.3358
# Epoch 13/20
# 3/3 [==============================] - 3s 1s/step - loss: 0.1639 - mae: 0.3372
# Epoch 14/20
# 3/3 [==============================] - 3s 1s/step - loss: 0.1638 - mae: 0.3370
# Epoch 15/20
# 3/3 [==============================] - 3s 1s/step - loss: 0.1629 - mae: 0.3369
# Epoch 16/20
# 3/3 [==============================] - 4s 1s/step - loss: 0.1630 - mae: 0.3403
# Epoch 17/20
# 3/3 [==============================] - 3s 1s/step - loss: 0.1623 - mae: 0.3418
# Epoch 18/20
# 3/3 [==============================] - 3s 1s/step - loss: 0.1621 - mae: 0.3427
# Epoch 19/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.1624 - mae: 0.3423
# Epoch 20/20
# 3/3 [==============================] - 3s 1s/step - loss: 0.1624 - mae: 0.3402
# Epoch 1/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1625 - mae: 0.3381
# Epoch 2/30
# 3/3 [==============================] - 4s 2s/step - loss: 0.1625 - mae: 0.3371
# Epoch 3/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1623 - mae: 0.3373
# Epoch 4/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1622 - mae: 0.3378
# Epoch 5/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.1621 - mae: 0.3391
# Epoch 6/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1637 - mae: 0.3430
# Epoch 7/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1627 - mae: 0.3409
# Epoch 8/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.1618 - mae: 0.3380
# Epoch 9/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1596 - mae: 0.3353
# Epoch 10/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1661 - mae: 0.3445
# Epoch 11/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.1644 - mae: 0.3406
# Epoch 12/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1647 - mae: 0.3377
# Epoch 13/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1653 - mae: 0.3451
# Epoch 14/30
# 3/3 [==============================] - 4s 2s/step - loss: 0.1627 - mae: 0.3386
# Epoch 15/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1643 - mae: 0.3362
# Epoch 16/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1635 - mae: 0.3361
# Epoch 17/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.1631 - mae: 0.3445
# Epoch 18/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1724 - mae: 0.3594
# Epoch 19/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1694 - mae: 0.3434
# Epoch 20/30
# 3/3 [==============================] - 4s 2s/step - loss: 0.1725 - mae: 0.3386
# Epoch 21/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1709 - mae: 0.3398
# Epoch 22/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1658 - mae: 0.3332
# Epoch 23/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.1641 - mae: 0.3300
# Epoch 24/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1648 - mae: 0.3322
# Epoch 25/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.1652 - mae: 0.3437
# Epoch 26/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1600 - mae: 0.3430
# Epoch 27/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1598 - mae: 0.3402
# Epoch 28/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.1593 - mae: 0.3394
# Epoch 29/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1595 - mae: 0.3409
# Epoch 30/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1559 - mae: 0.3296
# Epoch 1/40
# 3/3 [==============================] - 5s 1s/step - loss: 0.1639 - mae: 0.3273
# Epoch 2/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1641 - mae: 0.3256
# Epoch 3/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1597 - mae: 0.3312
# Epoch 4/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.1557 - mae: 0.3335
# Epoch 5/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1533 - mae: 0.3255
# Epoch 6/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1655 - mae: 0.3341
# Epoch 7/40
# 3/3 [==============================] - 5s 1s/step - loss: 0.1663 - mae: 0.3343
# Epoch 8/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1648 - mae: 0.3351
# Epoch 9/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1561 - mae: 0.3303
# Epoch 10/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.1600 - mae: 0.3439
# Epoch 11/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1666 - mae: 0.3477
# Epoch 12/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1620 - mae: 0.3375
# Epoch 13/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1544 - mae: 0.3272
# Epoch 14/40
# 3/3 [==============================] - 4s 1s/step - loss: 0.1547 - mae: 0.3320
# Epoch 15/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1508 - mae: 0.3283
# Epoch 16/40
# 3/3 [==============================] - 4s 1s/step - loss: 0.1487 - mae: 0.3259
# Epoch 17/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1441 - mae: 0.3204
# Epoch 18/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1463 - mae: 0.3184
# Epoch 19/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.1456 - mae: 0.3119
# Epoch 20/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1601 - mae: 0.3407
# Epoch 21/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1485 - mae: 0.3116
# Epoch 22/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.1512 - mae: 0.2917
# Epoch 23/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1600 - mae: 0.3030
# Epoch 24/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1697 - mae: 0.3276
# Epoch 25/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1675 - mae: 0.3333
# Epoch 26/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.1620 - mae: 0.3221
# Epoch 27/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1597 - mae: 0.3246
# Epoch 28/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1546 - mae: 0.3276
# Epoch 29/40
# 3/3 [==============================] - 4s 1s/step - loss: 0.1491 - mae: 0.3195
# Epoch 30/40
# 3/3 [==============================] - 5s 2s/step - loss: 0.1383 - mae: 0.2992
# Epoch 31/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1351 - mae: 0.2961
# Epoch 32/40
# 3/3 [==============================] - 4s 1s/step - loss: 0.1306 - mae: 0.2984
# Epoch 33/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1240 - mae: 0.2899
# Epoch 34/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1214 - mae: 0.2781
# Epoch 35/40
# 3/3 [==============================] - 4s 1s/step - loss: 0.1367 - mae: 0.2780
# Epoch 36/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1459 - mae: 0.2771
# Epoch 37/40
# 3/3 [==============================] - 4s 1s/step - loss: 0.1290 - mae: 0.2587
# Epoch 38/40
# 3/3 [==============================] - 4s 1s/step - loss: 0.1353 - mae: 0.2668
# Epoch 39/40
# 3/3 [==============================] - 3s 1s/step - loss: 0.1300 - mae: 0.2566
# Epoch 40/40
# 3/3 [==============================] - 4s 1s/step - loss: 0.1513 - mae: 0.2895
# Epoch 1/20
# 2/2 [==============================] - 3s 1s/step - loss: 0.1394 - mae: 0.3184
# Epoch 2/20
# 2/2 [==============================] - 2s 1s/step - loss: 0.1353 - mae: 0.3095
# Epoch 3/20
# 2/2 [==============================] - 2s 1s/step - loss: 0.1237 - mae: 0.2613
# Epoch 4/20
# 2/2 [==============================] - 2s 1s/step - loss: 0.1290 - mae: 0.2700
# Epoch 5/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.1207 - mae: 0.2652
# Epoch 6/20
# 2/2 [==============================] - 2s 1s/step - loss: 0.1171 - mae: 0.2625
# Epoch 7/20
# 2/2 [==============================] - 2s 1s/step - loss: 0.1194 - mae: 0.2653
# Epoch 8/20
# 2/2 [==============================] - 2s 1s/step - loss: 0.1145 - mae: 0.2662
# Epoch 9/20
# 2/2 [==============================] - 2s 1s/step - loss: 0.1152 - mae: 0.2645
# Epoch 10/20
# 2/2 [==============================] - 4s 2s/step - loss: 0.1052 - mae: 0.2454
# Epoch 11/20
# 2/2 [==============================] - 2s 1s/step - loss: 0.1010 - mae: 0.2315
# Epoch 12/20
# 2/2 [==============================] - 2s 1s/step - loss: 0.1151 - mae: 0.2397
# Epoch 13/20
# 2/2 [==============================] - 2s 1s/step - loss: 0.1083 - mae: 0.2320
# Epoch 14/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.0992 - mae: 0.2168
# Epoch 15/20
# 2/2 [==============================] - 2s 1s/step - loss: 0.1010 - mae: 0.2188
# Epoch 16/20
# 2/2 [==============================] - 2s 1s/step - loss: 0.1019 - mae: 0.2203
# Epoch 17/20
# 2/2 [==============================] - 2s 1s/step - loss: 0.1015 - mae: 0.2186
# Epoch 18/20
# 2/2 [==============================] - 2s 1s/step - loss: 0.0976 - mae: 0.2045
# Epoch 19/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.1001 - mae: 0.2005
# Epoch 20/20
# 2/2 [==============================] - 3s 1s/step - loss: 0.0936 - mae: 0.1908
# Epoch 1/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.1313 - mae: 0.2276
# Epoch 2/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.1417 - mae: 0.2426
# Epoch 3/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.1807 - mae: 0.2860
# Epoch 4/30
# 2/2 [==============================] - 3s 2s/step - loss: 0.1998 - mae: 0.3207
# Epoch 5/30
# 2/2 [==============================] - 3s 1s/step - loss: 0.1955 - mae: 0.3430
# Epoch 6/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.1643 - mae: 0.3440
# Epoch 7/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.1818 - mae: 0.3786
# Epoch 8/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.1722 - mae: 0.3586
# Epoch 9/30
# 2/2 [==============================] - 3s 2s/step - loss: 0.1665 - mae: 0.3501
# Epoch 10/30
# 2/2 [==============================] - 3s 1s/step - loss: 0.1538 - mae: 0.3236
# Epoch 11/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.1455 - mae: 0.3068
# Epoch 12/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.1318 - mae: 0.2841
# Epoch 13/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.1626 - mae: 0.3080
# Epoch 14/30
# 2/2 [==============================] - 4s 2s/step - loss: 0.1995 - mae: 0.3433
# Epoch 15/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.2013 - mae: 0.3225
# Epoch 16/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.2090 - mae: 0.3258
# Epoch 17/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.2226 - mae: 0.3551
# Epoch 18/30
# 2/2 [==============================] - 3s 1s/step - loss: 0.2015 - mae: 0.3435
# Epoch 19/30
# 2/2 [==============================] - 3s 2s/step - loss: 0.2049 - mae: 0.3509
# Epoch 20/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.2152 - mae: 0.3562
# Epoch 21/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.2155 - mae: 0.3487
# Epoch 22/30
# 2/2 [==============================] - 5s 3s/step - loss: 0.1992 - mae: 0.3530
# Epoch 23/30
# 2/2 [==============================] - 4s 2s/step - loss: 0.2208 - mae: 0.3657
# Epoch 24/30
# 2/2 [==============================] - 3s 1s/step - loss: 0.2532 - mae: 0.3445
# Epoch 25/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.2676 - mae: 0.3358
# Epoch 26/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.2631 - mae: 0.3202
# Epoch 27/30
# 2/2 [==============================] - 3s 1s/step - loss: 0.2694 - mae: 0.3221
# Epoch 28/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.2684 - mae: 0.3190
# Epoch 29/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.2684 - mae: 0.3186
# Epoch 30/30
# 2/2 [==============================] - 2s 1s/step - loss: 0.2692 - mae: 0.3213
# Epoch 1/40
# 2/2 [==============================] - 3s 2s/step - loss: 0.2689 - mae: 0.3209
# Epoch 2/40
# 2/2 [==============================] - 3s 1s/step - loss: 0.2638 - mae: 0.3197
# Epoch 3/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2637 - mae: 0.3222
# Epoch 4/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2540 - mae: 0.3268
# Epoch 5/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2536 - mae: 0.3248
# Epoch 6/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2641 - mae: 0.3224
# Epoch 7/40
# 2/2 [==============================] - 3s 2s/step - loss: 0.2617 - mae: 0.3118
# Epoch 8/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2626 - mae: 0.3127
# Epoch 9/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2624 - mae: 0.3127
# Epoch 10/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2614 - mae: 0.3123
# Epoch 11/40
# 2/2 [==============================] - 3s 2s/step - loss: 0.2611 - mae: 0.3129
# Epoch 12/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2670 - mae: 0.3198
# Epoch 13/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2658 - mae: 0.3153
# Epoch 14/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2726 - mae: 0.3110
# Epoch 15/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2710 - mae: 0.3062
# Epoch 16/40
# 2/2 [==============================] - 3s 2s/step - loss: 0.2703 - mae: 0.3060
# Epoch 17/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2703 - mae: 0.3065
# Epoch 18/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2694 - mae: 0.3039
# Epoch 19/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2694 - mae: 0.3040
# Epoch 20/40
# 2/2 [==============================] - 3s 2s/step - loss: 0.2758 - mae: 0.3077
# Epoch 21/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2747 - mae: 0.3039
# Epoch 22/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2810 - mae: 0.3076
# Epoch 23/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2811 - mae: 0.3078
# Epoch 24/40
# 2/2 [==============================] - 3s 2s/step - loss: 0.2809 - mae: 0.3075
# Epoch 25/40
# 2/2 [==============================] - 3s 1s/step - loss: 0.2808 - mae: 0.3073
# Epoch 26/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2808 - mae: 0.3072
# Epoch 27/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2807 - mae: 0.3071
# Epoch 28/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2806 - mae: 0.3068
# Epoch 29/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2805 - mae: 0.3067
# Epoch 30/40
# 2/2 [==============================] - 3s 1s/step - loss: 0.2804 - mae: 0.3065
# Epoch 31/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2804 - mae: 0.3065
# Epoch 32/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2803 - mae: 0.3064
# Epoch 33/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2803 - mae: 0.3063
# Epoch 34/40
# 2/2 [==============================] - 4s 2s/step - loss: 0.2803 - mae: 0.3063
# Epoch 35/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2803 - mae: 0.3063
# Epoch 36/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2803 - mae: 0.3062
# Epoch 37/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2803 - mae: 0.3062
# Epoch 38/40
# 2/2 [==============================] - 3s 2s/step - loss: 0.2802 - mae: 0.3061
# Epoch 39/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2802 - mae: 0.3061
# Epoch 40/40
# 2/2 [==============================] - 2s 1s/step - loss: 0.2802 - mae: 0.3061

# %%
# Número de Batchs i Epochs a provar
batch_sizes = [16, 32, 64]
epochs_values = [20, 30, 40]

best_mae = float('inf')
best_batch_size = None
best_epochs = None

# Emmagatzemar els hiperparàmetres
units_gru_2, units_gru, units_dense, lr = grid_result.best_params_['units_gru_2'], grid_result.best_params_['units_gru'], grid_result.best_params_['units_dense'], grid_result.best_params_['lr']

# Cerca d'hiperparàmetres
for batch_size in batch_sizes:
    for epochs in epochs_values:
        model = build_model(lr=lr, units_gru=units_gru, units_gru_2=units_gru_2, units_dense=units_dense)
        model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, verbose=0)

        _, test_mae = model.evaluate(X_test, y_test, verbose=0)

        if test_mae < best_mae:
            best_mae = test_mae
            best_batch_size = batch_size
            best_epochs = epochs

print("Millor combinació d'hiperparàmetres:")
print("Batch size:", best_batch_size)
print("Epochs:", best_epochs)
print("MAE en el conjunt de prova:", best_mae)
# Out:
# Millor combinació d'hiperparàmetres:
# Batch size: 16
# Epochs: 20
# MAE en el conjunt de prova: 0.3963334262371063

# %% [markdown]
# # Model final

# %%
#hiperparàmetres
units_gru_2, units_gru, units_dense, lr = grid_result.best_params_['units_gru_2'], grid_result.best_params_['units_gru'], grid_result.best_params_['units_dense'], grid_result.best_params_['lr']
batch_size = best_batch_size

#creació i compilació model
final_model = build_model(lr=lr, units_gru=units_gru, units_gru_2=units_gru_2, units_dense=units_dense)

# Creació del DataLoader
train_dataset = create_dataloader(X_train, y_train, batch_size)

#entrenament del model amb els hyperparametres trobats
final_model.fit(train_dataset, epochs=best_epochs, verbose=0)

#Evaluació amb el conjunt test
test_dataset = create_dataloader(X_test, y_test, batch_size)
test_loss, test_mae = final_model.evaluate(test_dataset, verbose=0)
print(f"Loss al conjunt de prova: {test_loss}")
print(f"MAE al conjunt de prova: {test_mae}")
# Out:
# Loss al conjunt de prova: 0.20440392196178436
# MAE al conjunt de prova: 0.39666947722435

# %%
y_pred = final_model.predict(X_test)
for i in range(len(y_test)):
  print(y_test[i],"                   ",y_pred[i])
# Out:
# 1/1 [==============================] - 1s 955ms/step
# 0.0                     [0.6151087]
# 0.8569766235351562                     [0.69594496]
# 1.0                     [0.66758496]
# 0.9870536804199219                     [0.7172315]
# 0.6351990127563476                     [0.7013795]
# 1.0                     [0.54390967]
# 0.0                     [0.69071686]
# 1.0                     [0.67489606]
# 0.9744159698486328                     [0.62560946]
# 0.0                     [0.6653189]
# 1.0                     [0.6073703]
# 0.0                     [0.6151087]
# 0.6449063873291015                     [0.6757499]
# 1.0                     [0.7029433]
# 0.8045121002197265                     [0.67877245]
# 0.9029817199707031                     [0.68749905]
# 1.0                     [0.70041317]
# 0.0                     [0.69970554]
# 0.0                     [0.6874515]
# 0.0                     [0.70898867]
# 1.0                     [0.6731295]
